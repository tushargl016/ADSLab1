# %%
import numpy as np
import math
import pandas as pd

# %%
df = pd.read_csv(open("F20000930.mdl",'rb'),header=None)

# %%
df
# Out:
#           0                    1                      2  3           4   5  \
# 0      BETA                SBeta                   Beta  0   288.67400   7
# 1       E/P          SEarn/Price         Earnings/Price  0    10.02280   8
# 2       B/P          SBook/Price             Book/Price  0     9.90204   9
# 3     YIELD      SDividend Yield         Dividend Yield  0     8.18746  10
# 4     TRADE    STrading Activity       Trading Activity  0    48.24200  11
# 5       RST         SRelStrength      Relative Strength  0   142.20700  12
# 6       CAP        SLogMarketCap      Log of Market Cap  0    15.02730  13
# 7      EVAR  SEarnings Variabili   Earnings Variability  0     6.89567  14
# 8       EGR     SEPS Growth Rate        EPS Growth Rate  0     8.70163  15
# 9       R/P           SRev/Price          Revenue/Price  0    17.50700  16
# 10  DEBT/EQ         SDebt/Equity            Debt/Equity  0     6.32963  17
# ...

# %%
df = pd.read_csv(open("F20000930c.csv",'rb'))

# %%
df
# Out:
#           *$$$                      CASH   0       100      0.1       1   0.2  \
# 0     00846U10  AGILENT TECHNOLOGIES INC  22  48.93750  16.7200  453.02  1.22
# 1     01381710                 ALCOA INC  31  25.31250   8.5000  866.00  1.23
# 2     00723110    ADMIRALTY BANCORP CL B   2   8.75000   7.8800    2.35  0.71
# 3     00431F10    ACCESS ANYTIME BANCORP   2   6.31250   7.5800    1.24  0.80
# 4     00371F20      ABLEAUCTIONS.COM INC   4   4.50000  27.7600   20.88  1.58
# 5     01853E20  ALLIANCE ATLANTIS COMMUN  21  17.28120  15.0800   25.41  0.72
# 6     00440310      ACE CASH EXPRESS INC   4  11.00000  11.4400   10.16  1.36
# 7     00504P10  ACTIVE APPAREL GROUP INC  14   3.84375  28.7992    2.49  0.84
# 8     00949P10      AIRTRAN HOLDINGS INC  34   4.43750  16.7100   65.73  0.65
# 9     03793910    APPLIED ANALYTICAL IND  24   7.75000  19.8400   17.49  1.02
# 10    02355920              AMERALIA INC  31   1.00000  34.7900    8.69  1.28
# ...

# %%
df = pd.read_csv(open("F20000930.cor",'rb'),header=None)

# %%
df
# Out:
#     0         1         2         3         4         5         6         7   \
# 0    1  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 1    0  1.000000  0.170690 -0.046764 -0.105239 -0.103948  0.161582 -0.107687
# 2    0  0.170690  1.000000  0.124669 -0.097592 -0.377933  0.355819 -0.264345
# 3    0 -0.046764  0.124669  1.000000  0.065769  0.140178 -0.109307 -0.150124
# 4    0 -0.105239 -0.097592  0.065769  1.000000  0.132409 -0.002560  0.156648
# 5    0 -0.103948 -0.377933  0.140178  0.132409  1.000000 -0.248449  0.168636
# 6    0  0.161582  0.355819 -0.109307 -0.002560 -0.248449  1.000000 -0.271054
# 7    0 -0.107687 -0.264345 -0.150124  0.156648  0.168636 -0.271054  1.000000
# 8    0 -0.431853 -0.180363 -0.001624  0.239357  0.186762 -0.146551  0.679112
# 9    0  0.213407  0.220906 -0.215145 -0.214839 -0.321576  0.213509 -0.444599
# 10   0  0.397879  0.480152  0.131020 -0.023296 -0.247003  0.138598 -0.354256
# ...
